# %%
from ultralytics import YOLO
import cv2
from pathlib import Path

# %%
image_dir = Path("laying_dataset/images")
image_files = sorted(image_dir.glob("*.png"))

for img_path in image_files:
    img = cv2.imread(str(img_path))
    height, width = img.shape[:2]
    print(f"{img_path.name}: {width} x {height}")
# Out:
# laying01.png: 1024 x 1024
# laying02.png: 1024 x 1024
# laying03.png: 1024 x 1024
# laying04.png: 1024 x 1024
# laying05.png: 1024 x 1024
# laying06.png: 1024 x 1024
# laying07.png: 1024 x 1024
# laying08.png: 1024 x 1024
# laying09.png: 1024 x 1024
# laying10.png: 1024 x 1024
# laying100.png: 1024 x 1024
# laying101.png: 1024 x 1024
# laying102.png: 1024 x 1024
# laying103.png: 1024 x 1024
# laying104.png: 1024 x 1024
# laying105.png: 1024 x 1024
# laying107.png: 1024 x 1024
# laying108.png: 1024 x 1024
# laying109.png: 1024 x 1024
# laying11.png: 1024 x 1024
# laying110.png: 1024 x 1024
# laying111.png: 1024 x 1024
# laying112.png: 1024 x 1024
# laying113.png: 1024 x 1024
# laying12.png: 1024 x 1024
# laying13.png: 1024 x 1024
# laying14.png: 1024 x 1024
# laying15.png: 1024 x 1024
# laying16.png: 1024 x 1024
# laying17.png: 1024 x 1024
# laying18.png: 1024 x 1024
# laying19.png: 1024 x 1024
# laying20.png: 1024 x 1024
# laying21.png: 1024 x 1024
# laying22.png: 1024 x 1024
# laying23.png: 1024 x 1024
# laying24.png: 1024 x 1024
# laying25.png: 1024 x 1024
# laying26.png: 1024 x 1024
# laying27.png: 1024 x 1024
# laying28.png: 1024 x 1024
# laying29.png: 1024 x 1024
# laying30.png: 1024 x 1024
# laying31.png: 1024 x 1024
# laying32.png: 1024 x 1024
# laying33.png: 1024 x 1024
# laying34.png: 1024 x 1024
# laying35.png: 1024 x 1024
# laying36.png: 1024 x 1024
# laying37.png: 1024 x 1024
# laying38.png: 1024 x 1024
# laying39.png: 1024 x 1024
# laying40.png: 1024 x 1024
# laying41.png: 1024 x 1024
# laying42.png: 1024 x 1024
# laying43.png: 1024 x 1024
# laying44.png: 1024 x 1024
# laying45.png: 1024 x 1024
# laying46.png: 1024 x 1024
# laying47.png: 1024 x 1024
# laying48.png: 1024 x 1024
# laying49.png: 1024 x 1024
# laying50.png: 1024 x 1024
# laying51.png: 1024 x 1024
# laying52.png: 1024 x 1024
# laying53.png: 1024 x 1024
# laying54.png: 1024 x 1024
# laying55.png: 1024 x 1024
# laying56.png: 1024 x 1024
# laying57.png: 1024 x 1024
# laying58.png: 1024 x 1024
# laying59.png: 1024 x 1024
# laying60.png: 1024 x 1024
# laying61.png: 1024 x 1024
# laying62.png: 1024 x 1024
# laying63.png: 1024 x 1024
# laying64.png: 1024 x 1024
# laying65.png: 1024 x 1024
# laying66.png: 1024 x 1024
# laying67.png: 1024 x 1024
# laying68.png: 1024 x 1024
# laying69.png: 1024 x 1024
# laying70.png: 1024 x 1024
# laying71.png: 1024 x 1024
# laying72.png: 1024 x 1024
# laying73.png: 1024 x 1024
# laying74.png: 1024 x 1024
# laying75.png: 1024 x 1024
# laying76.png: 1024 x 1024
# laying77.png: 1024 x 1024
# laying78.png: 1024 x 1024
# laying79.png: 1024 x 1024
# laying80.png: 1024 x 1024
# laying82.png: 1024 x 1024
# laying83.png: 1024 x 1024
# laying84.png: 1024 x 1024
# laying85.png: 1024 x 1024
# laying86.png: 1024 x 1024
# laying87.png: 1024 x 1024
# laying88.png: 1024 x 1024
# laying89.png: 1024 x 1024
# laying90.png: 1024 x 1024
# laying91.png: 1024 x 1024
# laying92.png: 1024 x 1024
# laying93.png: 1024 x 1024
# laying94.png: 1024 x 1024
# laying95.png: 1024 x 1024
# laying96.png: 1024 x 1024
# laying97.png: 1024 x 1024
# laying98.png: 1024 x 1024
# laying99.png: 1024 x 1024

# %%
model = YOLO('yolo11n-pose.pt')

results = model.train(data="laying_dataset/dataset.yaml", epochs=5, imgsz=1024)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-pose.pt to 'yolo11n-pose.pt': 100% ━━━━━━━━━━━━ 6.0MB 21.5MB/s 0.3s.2s<0.1s
# Ultralytics 8.3.248  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=laying_dataset/dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Raghav\Downloads\Fire_Model\runs\pose\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\engine\trainer.py:649, in BaseTrainer.get_dataset(self)
#     643 elif str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     644     "detect",
#     645     "segment",
#     646     "pose",
#     647     "obb",
#     648 }:
# --> 649     data = check_det_dataset(self.args.data)
#     650     if "yaml_file" in data:
#
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\data\utils.py:462, in check_det_dataset(dataset, autodownload)
#     461     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 462     raise FileNotFoundError(m)
#     463 t = time.time()
#
# FileNotFoundError: Dataset 'laying_dataset/dataset.yaml' images not found, missing path 'C:\Users\raghavmehta\Downloads\CCTV-Detect\laying_dataset\images'
# Note dataset download directory is 'C:\Users\Raghav\Downloads\datasets'. You can update this in 'C:\Users\Raghav\AppData\Roaming\Ultralytics\settings.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 model = YOLO('yolo11n-pose.pt')
# ----> 3 results = model.train(data="laying_dataset/dataset.yaml", epochs=5, imgsz=1024)
#
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\engine\model.py:768, in Model.train(self, trainer, **kwargs)
#     765 if args.get("resume"):
#     766     args["resume"] = self.ckpt_path
# --> 768 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     769 if not args.get("resume"):  # manually set model only if not resuming
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\models\yolo\pose\train.py:55, in PoseTrainer.__init__(self, cfg, overrides, _callbacks)
#      53     overrides = {}
#      54 overrides["task"] = "pose"
# ---> 55 super().__init__(cfg, overrides, _callbacks)
#
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\models\yolo\detect\train.py:63, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      55 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks=None):
#      56     """Initialize a DetectionTrainer object for training YOLO object detection models.
#      57
#      58     Args:
#    (...)     61         _callbacks (list, optional): List of callback functions to be executed during training.
#      62     """
# ---> 63     super().__init__(cfg, overrides, _callbacks)
#
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\engine\trainer.py:163, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     161 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     162 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 163     self.data = self.get_dataset()
#     165 self.ema = None
#     167 # Optimization utils init
#
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\models\yolo\pose\train.py:107, in PoseTrainer.get_dataset(self)
#      98 def get_dataset(self) -> dict[str, Any]:
#      99     """Retrieve the dataset and ensure it contains the required `kpt_shape` key.
#     100
#     101     Returns:
#    (...)    105         KeyError: If the `kpt_shape` key is not present in the dataset.
#     106     """
# --> 107     data = super().get_dataset()
#     108     if "kpt_shape" not in data:
#     109         raise KeyError(f"No `kpt_shape` in the {self.args.data}. See https://docs.ultralytics.com/datasets/pose/")
#
# File ~\downloads\CCTV-Detect\.venv\Lib\site-packages\ultralytics\engine\trainer.py:653, in BaseTrainer.get_dataset(self)
#     651             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     652 except Exception as e:
# --> 653     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     654 if self.args.single_cls:
#     655     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset 'laying_dataset/dataset.yaml' error  Dataset 'laying_dataset/dataset.yaml' images not found, missing path 'C:\Users\raghavmehta\Downloads\CCTV-Detect\laying_dataset\images'
# Note dataset download directory is 'C:\Users\Raghav\Downloads\datasets'. You can update this in 'C:\Users\Raghav\AppData\Roaming\Ultralytics\settings.json'
