# %%
from ultralytics import YOLO
import cv2
from pathlib import Path

# %%
image_dir = Path("laying_dataset/images")
image_files = sorted(image_dir.glob("*.png"))

for img_path in image_files:
    img = cv2.imread(str(img_path))
    height, width = img.shape[:2]
    print(f"{img_path.name}: {width} x {height}")
# Out:
# laying01.png: 1024 x 1024
# laying02.png: 1024 x 1024
# laying03.png: 1024 x 1024
# laying04.png: 1024 x 1024
# laying05.png: 1024 x 1024
# laying06.png: 1024 x 1024
# laying07.png: 1024 x 1024
# laying08.png: 1024 x 1024
# laying09.png: 1024 x 1024
# laying10.png: 1024 x 1024
# laying100.png: 1024 x 1024
# laying101.png: 1024 x 1024
# laying102.png: 1024 x 1024
# laying103.png: 1024 x 1024
# laying104.png: 1024 x 1024
# laying105.png: 1024 x 1024
# laying107.png: 1024 x 1024
# laying108.png: 1024 x 1024
# laying109.png: 1024 x 1024
# laying11.png: 1024 x 1024
# laying110.png: 1024 x 1024
# laying111.png: 1024 x 1024
# laying112.png: 1024 x 1024
# laying113.png: 1024 x 1024
# laying12.png: 1024 x 1024
# laying13.png: 1024 x 1024
# laying14.png: 1024 x 1024
# laying15.png: 1024 x 1024
# laying16.png: 1024 x 1024
# laying17.png: 1024 x 1024
# laying18.png: 1024 x 1024
# laying19.png: 1024 x 1024
# laying20.png: 1024 x 1024
# laying21.png: 1024 x 1024
# laying22.png: 1024 x 1024
# laying23.png: 1024 x 1024
# laying24.png: 1024 x 1024
# laying25.png: 1024 x 1024
# laying26.png: 1024 x 1024
# laying27.png: 1024 x 1024
# laying28.png: 1024 x 1024
# laying29.png: 1024 x 1024
# laying30.png: 1024 x 1024
# laying31.png: 1024 x 1024
# laying32.png: 1024 x 1024
# laying33.png: 1024 x 1024
# laying34.png: 1024 x 1024
# laying35.png: 1024 x 1024
# laying36.png: 1024 x 1024
# laying37.png: 1024 x 1024
# laying38.png: 1024 x 1024
# laying39.png: 1024 x 1024
# laying40.png: 1024 x 1024
# laying41.png: 1024 x 1024
# laying42.png: 1024 x 1024
# laying43.png: 1024 x 1024
# laying44.png: 1024 x 1024
# laying45.png: 1024 x 1024
# laying46.png: 1024 x 1024
# laying47.png: 1024 x 1024
# laying48.png: 1024 x 1024
# laying49.png: 1024 x 1024
# laying50.png: 1024 x 1024
# laying51.png: 1024 x 1024
# laying52.png: 1024 x 1024
# laying53.png: 1024 x 1024
# laying54.png: 1024 x 1024
# laying55.png: 1024 x 1024
# laying56.png: 1024 x 1024
# laying57.png: 1024 x 1024
# laying58.png: 1024 x 1024
# laying59.png: 1024 x 1024
# laying60.png: 1024 x 1024
# laying61.png: 1024 x 1024
# laying62.png: 1024 x 1024
# laying63.png: 1024 x 1024
# laying64.png: 1024 x 1024
# laying65.png: 1024 x 1024
# laying66.png: 1024 x 1024
# laying67.png: 1024 x 1024
# laying68.png: 1024 x 1024
# laying69.png: 1024 x 1024
# laying70.png: 1024 x 1024
# laying71.png: 1024 x 1024
# laying72.png: 1024 x 1024
# laying73.png: 1024 x 1024
# laying74.png: 1024 x 1024
# laying75.png: 1024 x 1024
# laying76.png: 1024 x 1024
# laying77.png: 1024 x 1024
# laying78.png: 1024 x 1024
# laying79.png: 1024 x 1024
# laying80.png: 1024 x 1024
# laying82.png: 1024 x 1024
# laying83.png: 1024 x 1024
# laying84.png: 1024 x 1024
# laying85.png: 1024 x 1024
# laying86.png: 1024 x 1024
# laying87.png: 1024 x 1024
# laying88.png: 1024 x 1024
# laying89.png: 1024 x 1024
# laying90.png: 1024 x 1024
# laying91.png: 1024 x 1024
# laying92.png: 1024 x 1024
# laying93.png: 1024 x 1024
# laying94.png: 1024 x 1024
# laying95.png: 1024 x 1024
# laying96.png: 1024 x 1024
# laying97.png: 1024 x 1024
# laying98.png: 1024 x 1024
# laying99.png: 1024 x 1024

# %%
model = YOLO('yolo11n-pose.pt')

results = model.train(data="laying_dataset/dataset.yaml", epochs=5, imgsz=1024)
# Out:
# Ultralytics 8.3.248 🚀 Python-3.13.9 torch-2.9.1 CPU (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=laying_dataset/dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/raghavmehta/Downloads/Fire_Model/runs/pose/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    715489  ultralytics.nn.modules.head.Pose             [2, [17, 3], [64, 128, 256]]
# YOLO11n-pose summary: 196 layers, 2,874,657 parameters, 2,874,641 gradients, 7.5 GFLOPs
#
# Transferred 535/541 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1924.6±405.5 MB/s, size: 1520.9 KB)
# train: Scanning /Users/raghavmehta/Downloads/CCTV-Detect/laying_dataset/labels... 111 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 111/111 1.3Kit/s 0.1s
# train: New cache created: /Users/raghavmehta/Downloads/CCTV-Detect/laying_dataset/labels.cache
# WARNING ⚠️ No 'flip_idx' array defined in data.yaml, disabling 'fliplr' and 'flipud' augmentations.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 10002.9±2555.9 MB/s, size: 1581.4 KB)
# val: Scanning /Users/raghavmehta/Downloads/CCTV-Detect/laying_dataset/labels.cache... 111 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 111/111 1.2Mit/s 0.0s0s
# Plotting labels to /Users/raghavmehta/Downloads/Fire_Model/runs/pose/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 0 dataloader workers
# Logging results to /Users/raghavmehta/Downloads/Fire_Model/runs/pose/train2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G     0.7812      4.139      0.316      5.321      1.376         29       1024: 29% ━━━───────── 2/7 15.2s/it 36.2s<1:16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 model = YOLO('yolo11n-pose.pt')
# ----> 3 results = model.train(data="laying_dataset/dataset.yaml", epochs=5, imgsz=1024)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/engine/model.py:773, in Model.train(self, trainer, **kwargs)
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     771     self.model = self.trainer.model
# --> 773 self.trainer.train()
#     774 # Update model and cfg after training
#     775 if RANK in {-1, 0}:
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/engine/trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/engine/trainer.py:427, in BaseTrainer._do_train(self)
#     425     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     426 else:
# --> 427     loss, self.loss_items = self.model(batch)
#     428 self.loss = loss.sum()
#     429 if RANK != -1:
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/tasks.py:136, in BaseModel.forward(self, x, *args, **kwargs)
#     123 """Perform forward pass of the model for either training or inference.
#     124
#     125 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    133     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     134 """
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 136     return self.loss(x, *args, **kwargs)
#     137 return self.predict(x, *args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/tasks.py:327, in BaseModel.loss(self, batch, preds)
#     324     self.criterion = self.init_criterion()
#     326 if preds is None:
# --> 327     preds = self.forward(batch["img"])
#     328 return self.criterion(preds, batch)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/tasks.py:137, in BaseModel.forward(self, x, *args, **kwargs)
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
#     136     return self.loss(x, *args, **kwargs)
# --> 137 return self.predict(x, *args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/tasks.py:154, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     152 if augment:
#     153     return self._predict_augment(x)
# --> 154 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/tasks.py:176, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     174 if profile:
#     175     self._profile_one_layer(m, x, dt)
# --> 176 x = m(x)  # run
#     177 y.append(x if m.i in self.save else None)  # save output
#     178 if visualize:
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/modules/head.py:359, in Pose.forward(self, x)
#     357 bs = x[0].shape[0]  # batch size
#     358 kpt = torch.cat([self.cv4[i](x[i]).view(bs, self.nk, -1) for i in range(self.nl)], -1)  # (bs, 17*3, h*w)
# --> 359 x = Detect.forward(self, x)
#     360 if self.training:
#     361     return x, kpt
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/modules/head.py:120, in Detect.forward(self, x)
#     117     return self.forward_end2end(x)
#     119 for i in range(self.nl):
# --> 120     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#     121 if self.training:  # Training path
#     122     return x
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/ultralytics/nn/modules/conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)     76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Downloads/CCTV-Detect/.venv/lib/python3.13/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
